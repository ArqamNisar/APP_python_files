# %%
import pandas as pd
data = [{'a': 1, 'b': 3},{'a':4, 'b' : 6, 'c' : 9}]

# %%
df = pd.DataFrame(data, index = ['first', 'second'])
print(df)
# Out:
#         a  b    c
# first   1  3  NaN
# second  4  6  9.0

# %%
import matplotlib.pyplot as plt
plt.bar([1,2,3],[4,5,6])
plt.show()
plt.xlabel('A')
plt.ylabel('B')
plt.legend()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
#Path to File
df = pd.read_csv("C:/Users/mnisar.rime19smme/Desktop/first-master/first-master/data.csv")
#Displaying CSV Data to Console
print(df.to_string())
#Plotting DataFrame
plt.plot(df)
plt.show()
# Out:
#    Col1    Col2   Col3   Col4
# 0     3  215.63  25.96  35.00
# 1     5  152.69  38.95  68.02
# 2     9  142.96  28.45   2.99
# 3     6   95.86  12.69   3.99
# 4     1   89.76  18.96   5.94
# 5     2  112.85  24.96   4.95
# 6     8  199.95  11.95   7.72
# 7     5  103.56  20.75   6.22
# 8     4  139.67  10.87  35.00
# 9     9  218.96  23.75   8.33
